# %% [markdown]
# <a href="https://colab.research.google.com/github/thaleson/datascience/blob/main/An%C3%A1lise_de_Dados_para_Finan%C3%A7as.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Data Science para Finanças**
# *por [Thaleson silva ](https://www.linkedin.com/in/thaleson-silva-9298a0296/)*
#
# ---
#
# <h1>Uma introdução à Análise Financeira</h1>
#
# Aplicações possíveis para Python e Finanças
#
# Seja para extrair informações de portais de investimento, analisar dados ou usar a Inteligência Artificial para decidir pontos de compra e venda, aprender Python no mundo dos investimentos é a decisão mais inteligente que você poderia ter.
#
# <center><img src="https://www.thepythoncode.com/media/articles/introduction-to-finance-and-technical-indicators-with-python.jpg" height="400px"></center>
#
# ## Ambiente Interativo
#
# Veja algumas das principais aplicações possíveis:
#
# * Criar dashboards com indicadores, múltiplos e cotações
# * Baixar automaticamente demonstrações financeiras da CVM
# * Realizar backtesting de maneira completamente automatizada
# * Enviar ordens de compra e venda de acordo com a sua estratégia
# * Analisar sentimentos de notícias para inferir como a empresa será afetada
# * Criar NFTs de maneira automatizada
# * Encontrar oportunidades únicas de NFT em marketplaces como OpenSea
# * Analisar várias criptomoedas simultaneamente
# * Otimizar sua carteira de investimentos
# * Realizar benchmarks com índices e fundos de investimento
#
# E essas são apenas algumas das possibilidades que você tem. Imagine a vantagem estratégica que isso representa em relação aos demais investidores.

# %% [markdown]
# ### Importar arquivos `csv` com as cotações do BBAS3.SA
#
# Para dar um exemplo de como é simples importar dados com o Pandas, veja o seguinte exemplo.
#
# Pelo site [Yahoo Finance](https://finance.yahoo.com/quote/BBAS3.SA/history?p=BBAS3.SA), baixei os dados da ação ordinária do Banco do Brasil (BBAS3) em formato `csv` e disponibilizei o arquivo [neste link](https://raw.githubusercontent.com/carlosfab/curso_data_science_na_pratica/master/modulo_02/BBAS3.SA.csv). Se eu abrir esse arquivo na minha máquina pelo Excel, é assim que ele vai aparecer para mim:
#
# <center><img src="https://raw.githubusercontent.com/carlosfab/curso_data_science_na_pratica/master/modulo_02/bbas3_excel.png" height="300px"></center>
#
# Importar esse mesmo arquivo usando o Pandas é tão simples quanto executar a função `pd.read_csv("local_do_arquivo.csv")`, informando qual o endereço que o `csv` se encontra (endereço na internet ou caminho na máquia local.
#
#
#
# Também é possível baixar arquivos por comandos do Terminal, criar diretórios e automatizar *pipelines*. Isso contribui mais ainda para que seu notebook seja replicável por qualquer pessoa.
#
# Vamos supor que você está usando um arquivo csv que se encontra no endereço ```https://raw.githubusercontent.com/carlosfab/dsnp2/master/datasets/BBAS3.SA.csv``` e quer baixar o mesmo:

# %%
# baixar o arquivo BBAS3.SA.csv
# !wget https://raw.githubusercontent.com/carlosfab/dsnp2/master/datasets/BBAS3.SA.csv

# ver o diretório
# !ls -l
# Out:
# --2022-05-12 23:30:04--  https://raw.githubusercontent.com/carlosfab/dsnp2/master/datasets/BBAS3.SA.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17286 (17K) [text/plain]
# Saving to: ‘BBAS3.SA.csv’
#
# BBAS3.SA.csv        100%[===================>]  16.88K  --.-KB/s    in 0s
#
# 2022-05-12 23:30:04 (74.6 MB/s) - ‘BBAS3.SA.csv’ saved [17286/17286]
#
# total 24
# -rw-r--r-- 1 root root 17286 May 12 23:30 BBAS3.SA.csv
# drwxr-xr-x 1 root root  4096 May  3 13:42 sample_data

# %% [markdown]
# Pronto! O arquivo `BBAS3.SA.csv` foi importado com sucesso e já está pronto para ser usado neste *notebook*.
#
# ### Conhecendo os componentes básicos do Pandas
#
# Os dois componentes básicos que a gente deve conhecer quando lidando com Pandas são `Series` e `DataFrame`.
#
# <center><img src="https://raw.githubusercontent.com/carlosfab/curso_data_science_na_pratica/master/modulo_02/componentes_pandas.png"></center>
#
# Simplificadamente, você pode pensar o `DataFrame` como sendo uma planilha de Excel, e `Series` como sendo apenas uma coluna individual.
#
# Apesar de parecer conceitualmente simples, estas duas estruturas nativas do Pandas facilitam muito o trabalho com dados, uma vez que elas podem armazenar qualquer tipo de dado.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/BBAS3.SA.csv")

# %%
df.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  247.000000  247.000000  247.000000  247.000000  247.000000
# mean    45.939960   46.576397   45.154615   45.838097   44.684901
# std      7.644318    7.475109    7.858680    7.704523    7.210382
# min     24.200001   25.000000   21.910000   22.129999   22.129999
# 25%     45.425002   46.145001   44.774999   45.415001   44.072172
# 50%     48.139999   48.779999   47.560001   47.990002   46.766251
# 75%     50.535000   51.125000   49.785000   50.460001   49.133178
# max     55.599998   55.700001   54.820000   55.180000   53.052986
#
#              Volume
# count  2.470000e+02
# mean   1.405295e+07
# std    8.021174e+06
# min    5.092200e+06
# 25%    8.997050e+06
# 50%    1.198600e+07
# 75%    1.587985e+07
# max    7.397800e+07

# %%
df['Volume'].std()
# Out:
# 8021174.313261291

# %%
plt.hist(df['Volume'], bins=10);

# %%
plt.scatter(df["Open"], df["Low"])

plt.savefig('sigmoidal.png')

# %% [markdown]
# ## Bibliotecas para Análise Financeira
#
# Apesar de termos muitas opções de bibliotecas em Python para analisar dados e operar no Mercado, infelizmento o Brasil ainda oferece bem menos alternativas que países como os Estados Unidos.
#
# Claro, isso se dá pelo volume relativo e pela própria maturidade do Mercado. Mas como esse ecossistema é um organismo vivo, em constante evolução, eu recomendo a todos que sempre mantenham uma rotina de pesquisa e estudos, pois isso vai permitir você identificar qualquer novidade ou ferramenta que facilite as suas análises.
#
#
# ### Baixando as cotaçãos do Yahoo Finance com a biblioteca `yfinance`
#
# Umas das bibliotecas mais fáceis e diretas de usar, é a `yfinance`, que fornece *features* como preços de abertura, fechamento, fechamento ajustado, máxima, mínima e voluma, bastando que o usuário do serviço informe o símbolo da ação.
#
# Vale ressaltar que ela não está instalada por padrão no Google Colab, sendo necessária a sua instalação.

# %%
# instalar biblioteca que não acompanha o Colab por padrão
# !pip install yfinance -q
# Out:
#      |████████████████████████████████| 63 kB 2.1 MB/s
#      |████████████████████████████████| 6.4 MB 21.3 MB/s
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.27.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.

# %%
# importar a biblioteca yfinance
import yfinance as yf

# %%
bbas3 = yf.Ticker('BBAS3.SA')

# %%
# pegar os dados históricos de mercado
hist = bbas3.history(period="max")

# %%
hist.head()
# Out:
#                 Open      High       Low     Close    Volume  Dividends  \
# Date
# 2000-01-03  1.224946  1.248278  1.195781  1.195781  514800.0        0.0
# 2000-01-04  1.195781  1.198697  1.138908  1.138908  314100.0        0.0
# 2000-01-05  1.137450  1.152033  1.096618  1.150574  478800.0        0.0
# 2000-01-06  1.150574  1.166615  1.137450  1.166615  205200.0        0.0
# 2000-01-07  1.166615  1.166615  1.140366  1.140366  394200.0        0.0
#
#             Stock Splits
# Date
# 2000-01-03           0.0
# 2000-01-04           0.0
# 2000-01-05           0.0
# 2000-01-06           0.0
# 2000-01-07           0.0

# %%
# mostrar dividendos, splits
bbas3.actions
# Out:
#             Dividends  Stock Splits
# Date
# 2007-06-04   0.000000           3.0
# 2009-06-23   0.180221           0.0
# 2009-08-14   0.190873           0.0
# 2009-09-22   0.185397           0.0
# 2009-11-13   0.122897           0.0
# ...               ...           ...
# 2021-09-14   0.184739           0.0
# 2021-11-23   0.393703           0.0
# 2021-12-14   0.174991           0.0
# 2022-03-03   0.824721           0.0
# 2022-03-15   0.210628           0.0
#
# [103 rows x 2 columns]

# %%
# ver informações da ação
bbas3.info
# Out:
# {'52WeekChange': 0.10044932,
#  'SandP52WeekChange': -0.043117344,
#  'address1': 'Banco do Brasil Building',
#  'address2': 'Quadra 5, Lote B Sector of Municipalities Norte Federal District',
#  'algorithm': None,
#  'annualHoldingsTurnover': None,
#  'annualReportExpenseRatio': None,
#  'ask': 35.12,
#  'askSize': 0,
#  'averageDailyVolume10Day': 12483010,
#  'averageVolume': 14244498,
#  'averageVolume10days': 12483010,
#  'beta': 0.779849,
#  'beta3Year': None,
#  'bid': 35.08,
#  'bidSize': 0,
#  'bookValue': 49.763,
#  'category': None,
#  'circulatingSupply': None,
#  'city': 'Brasília',
#  'companyOfficers': [],
#  'country': 'Brazil',
#  'currency': 'BRL',
#  'currentPrice': 35.16,
#  'currentRatio': None,
#  'dateShortInterest': None,
#  'dayHigh': 35.35,
#  'dayLow': 34.54,
#  'debtToEquity': None,
#  'dividendRate': 1.6,
#  'dividendYield': 0.0473,
#  'earningsGrowth': 0.731,
#  'earningsQuarterlyGrowth': 0.673,
#  'ebitda': None,
#  'ebitdaMargins': 0,
#  'enterpriseToEbitda': None,
#  'enterpriseToRevenue': 12.281,
#  'enterpriseValue': 909159038976,
#  'exDividendDate': 1647302400,
#  'exchange': 'SAO',
#  'exchangeTimezoneName': 'America/Sao_Paulo',
#  'exchangeTimezoneShortName': 'BRT',
#  'expireDate': None,
#  'fiftyDayAverage': 34.3228,
#  'fiftyTwoWeekHigh': 36.75,
#  'fiftyTwoWeekLow': 27.74,
#  'financialCurrency': 'BRL',
#  'fiveYearAverageReturn': None,
#  'fiveYearAvgDividendYield': 3.53,
#  'floatShares': 1286997266,
#  'forwardEps': 8.51,
#  'forwardPE': 4.13161,
#  'freeCashflow': None,
#  'fromCurrency': None,
#  'fullTimeEmployees': 84597,
#  'fundFamily': None,
#  'fundInceptionDate': None,
#  'gmtOffSetMilliseconds': '-10800000',
#  'grossMargins': 0,
#  'grossProfits': 73278684000,
#  'heldPercentInsiders': 0.5,
#  'heldPercentInstitutions': 0.17904,
#  'impliedSharesOutstanding': 0,
#  'industry': 'Banks—Regional',
#  'isEsgPopulated': False,
#  'lastCapGain': None,
#  'lastDividendDate': 1647302400,
#  'lastDividendValue': 0.210628,
#  'lastFiscalYearEnd': 1640908800,
#  'lastMarket': None,
#  'lastSplitDate': 1180915200,
#  'lastSplitFactor': '3:1',
#  'legalType': None,
#  'logo_url': 'https://logo.clearbit.com/bb.com.br',
#  'longBusinessSummary': 'Banco do Brasil S.A., together with its subsidiaries, provides banking products and services for individuals, companies, and public sectors in Brazil and internationally. The company operates through Banking, Investments, Fund Management, Insurance (Insurance, Pension, and Capitalization), Payment Methods, and Other segments. The Banking segment offers various products and services, including deposits, loans, and other services to retail, wholesale, and public sector markets, as well as to micro-entrepreneurs. The Investments segment engages in the structuring and distribution of debts and equity instruments in primary and secondary markets; and provision of financial services. The Fund Management segment is involved in the purchase, sale, and custody of securities, as well as the management of portfolios, and investment funds and clubs. The Insurance, Pension and Capitalization segment provides life, property, and automobile insurance products, as well as private pension and capitalization plans. The Payment Methods segment is involved in the capturing, transmission, processing, and financial settlement of for electronic payment transactions. The Other segment engages in the provision of credit recovery and consortium management services; development, manufacturing, sale, rental, and integration of digital electronic systems, peripherals, programs, inputs, and computing supplies; sale of airline tickets; and lodging and organization of events. Banco do Brasil S.A. was incorporated in 1808 and is headquartered in Brasília, Brazil.',
#  'longName': 'Banco do Brasil S.A.',
#  'market': 'br_market',
#  'marketCap': 100325548032,
#  'maxAge': 1,
#  'maxSupply': None,
#  'messageBoardId': 'finmb_874155',
#  'morningStarOverallRating': None,
#  'morningStarRiskRating': None,
#  'mostRecentQuarter': 1640908800,
#  'navPrice': None,
#  'netIncomeToCommon': 19574419456,
#  'nextFiscalYearEnd': 1703980800,
#  'numberOfAnalystOpinions': 17,
#  'open': 34.8,
#  'openInterest': None,
#  'operatingCashflow': -117414223872,
#  'operatingMargins': 0.40193,
#  'payoutRatio': 0.2925,
#  'pegRatio': 0.3,
#  'phone': '55 80 0729 5285',
#  'preMarketPrice': None,
#  'previousClose': 34.29,
#  'priceHint': 2,
#  'priceToBook': 0.70654905,
#  'priceToSalesTrailing12Months': 1.3551683,
#  'profitMargins': 0.26624,
#  'quickRatio': None,
#  'quoteType': 'EQUITY',
#  'recommendationKey': 'buy',
#  'recommendationMean': 2,
#  'regularMarketDayHigh': 35.35,
#  'regularMarketDayLow': 34.54,
#  'regularMarketOpen': 34.8,
#  'regularMarketPreviousClose': 34.29,
#  'regularMarketPrice': 35.16,
#  'regularMarketVolume': 24462200,
#  'returnOnAssets': 0.01165,
#  'returnOnEquity': 0.15683,
#  'revenueGrowth': 0.076,
#  'revenuePerShare': 25.944,
#  'revenueQuarterlyGrowth': None,
#  'sector': 'Financial Services',
#  'sharesOutstanding': 2853400064,
#  'sharesPercentSharesOut': None,
#  'sharesShort': None,
#  'sharesShortPreviousMonthDate': None,
#  'sharesShortPriorMonth': None,
#  'shortName': 'BRASIL      ON      NM',
#  'shortPercentOfFloat': None,
#  'shortRatio': None,
#  'startDate': None,
#  'state': 'DF',
#  'strikePrice': None,
#  'symbol': 'BBAS3.SA',
#  'targetHighPrice': 60.4,
#  'targetLowPrice': 35,
#  'targetMeanPrice': 46.26,
#  'targetMedianPrice': 45,
#  'threeYearAverageReturn': None,
#  'toCurrency': None,
#  'totalAssets': None,
#  'totalCash': 73614458880,
#  'totalCashPerShare': 25.799,
#  'totalDebt': 885121417216,
#  'totalRevenue': 74031800320,
#  'tradeable': False,
#  'trailingAnnualDividendRate': 2.639,
#  'trailingAnnualDividendYield': 0.07696121,
#  'trailingEps': 6.86,
#  'trailingPE': 5.1253643,
#  'twoHundredDayAverage': 31.5926,
#  'volume': 24462200,
#  'volume24Hr': None,
#  'volumeAllCurrencies': None,
#  'website': 'https://www.bb.com.br',
#  'yield': None,
#  'ytdReturn': None}

# %%
bbas3.financials
# Out:
#                                            2021-12-31     2020-12-31  \
# Research Development                             None           None
# Effect Of Accounting Charges                     None           None
# Income Before Tax                       25757215000.0  12821042000.0
# Minority Interest                        2862168000.0   2403457000.0
# Net Income                              19710402000.0  12697385000.0
# Selling General Administrative          35629827000.0  34047198000.0
# Gross Profit                            73278684000.0  57746081000.0
# Ebit                                              0.0            0.0
# Operating Income                        29755578000.0  13805379000.0
# Other Operating Expenses                 7893279000.0   9893504000.0
# Interest Expense                                 None           None
# Extraordinary Items                              None           None
# Non Recurring                                    None           None
# Other Items                                      None           None
# Income Tax Expense                       4441300000.0  -1452865000.0
# Total Revenue                           74031801000.0  58483157000.0
# Total Operating Expenses                44276223000.0  44677778000.0
# Cost Of Revenue                           753117000.0    737076000.0
# Total Other Income Expense Net          -3998363000.0   -984337000.0
# Discontinued Operations                          None           None
# Net Income From Continuing Ops          21315915000.0  14273907000.0
# Net Income Applicable To Common Shares  19574419000.0  12512155000.0
#
#                                            2019-12-31     2018-12-31
# Research Development                             None           None
# Effect Of Accounting Charges                     None           None
# Income Before Tax                       13783434000.0  19025243000.0
# Minority Interest                        1903656000.0   2510915000.0
# Net Income                              18162067000.0  12862026000.0
# Selling General Administrative          34847301000.0  33261795000.0
# Gross Profit                            61011653000.0  59618435000.0
# Ebit                                              0.0            0.0
# Operating Income                        17036523000.0  20312182000.0
# Other Operating Expenses                 9127829000.0   6044458000.0
# Interest Expense                                 None           None
# Extraordinary Items                              None           None
# Non Recurring                                    None           None
# Other Items                                      None           None
# Income Tax Expense                      -6860500000.0   4767368000.0
# Total Revenue                           61745862000.0  60334372000.0
# Total Operating Expenses                44709339000.0  40022190000.0
# Cost Of Revenue                           734209000.0    715937000.0
# Total Other Income Expense Net          -3253089000.0  -1286939000.0
# Discontinued Operations                          None           None
# Net Income From Continuing Ops          20643934000.0  14257875000.0
# Net Income Applicable To Common Shares  17899349000.0  12648803000.0

# %%
bbas3.quarterly_financials
# Out:
#                                            2021-12-31     2021-09-30  \
# Research Development                             None           None
# Effect Of Accounting Charges                     None           None
# Income Before Tax                        7406253000.0   6760047000.0
# Minority Interest                        2862168000.0   2957922000.0
# Net Income                               5351963000.0   4608838000.0
# Selling General Administrative           9197307000.0   8493555000.0
# Gross Profit                            18207474000.0  17857959000.0
# Ebit                                              0.0            0.0
# Operating Income                         7745684000.0   7670088000.0
# Other Operating Expenses                 1264483000.0   1694316000.0
# Interest Expense                                 None           None
# Extraordinary Items                              None           None
# Non Recurring                                    None           None
# Other Items                                      None           None
# Income Tax Expense                       1560384000.0   1753502000.0
# Total Revenue                           18397749000.0  18056403000.0
# Total Operating Expenses                10652065000.0  10386315000.0
# Cost Of Revenue                           190275000.0    198444000.0
# Total Other Income Expense Net           -339431000.0   -910041000.0
# Discontinued Operations                          None           None
# Net Income From Continuing Ops           5845869000.0   5006545000.0
# Net Income Applicable To Common Shares   5215980000.0   4634006000.0
#
#                                            2021-06-30     2021-03-31
# Research Development                             None           None
# Effect Of Accounting Charges                     None           None
# Income Before Tax                        6852585000.0   4738330000.0
# Minority Interest                        2564049000.0   2738063000.0
# Net Income                               5523694000.0   4225907000.0
# Selling General Administrative           8698104000.0   9240861000.0
# Gross Profit                            19300757000.0  17912494000.0
# Ebit                                              0.0            0.0
# Operating Income                        10560142000.0   3779664000.0
# Other Operating Expenses                   42511000.0   4891969000.0
# Interest Expense                                 None           None
# Extraordinary Items                              None           None
# Non Recurring                                    None           None
# Other Items                                      None           None
# Income Tax Expense                       1016592000.0    110822000.0
# Total Revenue                           19485053000.0  18092596000.0
# Total Operating Expenses                 8924911000.0  14312932000.0
# Cost Of Revenue                           184296000.0    180102000.0
# Total Other Income Expense Net          -3707557000.0    958666000.0
# Discontinued Operations                          None           None
# Net Income From Continuing Ops           5835993000.0   4627508000.0
# Net Income Applicable To Common Shares   5567231000.0   4157202000.0

# %%
bbas3.major_holders
# Out:
#         0                                      1
# 0  50.00%        % of Shares Held by All Insider
# 1  17.90%       % of Shares Held by Institutions
# 2  35.81%        % of Float Held by Institutions
# 3     440  Number of Institutions Holding Shares

# %%
bbas3.institutional_holders
# Out:
#                                               Holder    Shares Date Reported  \
# 0                            iShares MSCI Brazil ETF  14448019    2022-02-27
# 1           Lazard Emerging Markets Equity Portfolio  12808226    2021-12-30
# 2  Vanguard International Stock Index-Emerging Ma...  12116306    2022-01-30
# 3  Vanguard International Stock Index-Total Intl ...  11184398    2022-01-30
# 4             iShares Core MSCI Emerging Markets ETF   7003555    2022-02-27
# 5                  Vanguard International Value Fund   5775000    2022-01-30
# 6          Delaware Ivy Emerging Markets Equity Fund   5128700    2021-12-30
# 7                      iShares ESG Aware MSCI EM ETF   4425322    2022-02-27
# 8  Schwab Strategic Tr-Schwab Fundamental Emg Mkt...   4257244    2022-02-27
# 9  PIMCO Equity Series-PIMCO RAE Emerging Markets Fd   4062900    2021-12-30
#
#     % Out      Value
# 0  0.0050  508714748
# 1  0.0045  369517320
# 2  0.0042  395718553
# 3  0.0039  365282438
# 4  0.0024  246595171
# 5  0.0020  188611500
# 6  0.0018  147962995
# 7  0.0015  155815587
# 8  0.0015  149897561
# 9  0.0014  117214665

# %%
bbas3.balance_sheet
# Out:
#                                     2021-12-31    2020-12-31    2019-12-31  \
# Intangible Assets                 7.031258e+09  6.220666e+09  5.920549e+09
# Total Liab                        1.787676e+12  1.598701e+12  1.372530e+12
# Total Stockholder Equity          1.419950e+11  1.245677e+11  1.066612e+11
# Minority Interest                 2.862168e+09  2.403457e+09  1.903656e+09
# Other Current Liab                6.841630e+10  5.659272e+10  5.015906e+10
# Total Assets                      1.932533e+12  1.725672e+12  1.481095e+12
# Common Stock                      9.000002e+10  9.000002e+10  6.700000e+10
# Other Current Assets              1.574565e+11  1.369531e+11  1.372411e+11
# Retained Earnings                 5.118029e+10  3.919847e+10  5.381466e+10
# Other Liab                        1.316896e+11  1.305880e+11  1.129271e+11
# Treasury Stock                    8.147050e+08 -4.630839e+09 -1.415342e+10
# Other Assets                      8.380945e+11  7.204665e+11  6.543640e+11
# Cash                              4.906528e+10  5.681434e+10  7.193602e+10
# Total Current Liabilities         1.487773e+12  1.278059e+12  1.063533e+12
# Deferred Long Term Asset Charges  5.662000e+10  5.814258e+10  5.946293e+10
# Short Long Term Debt              7.169084e+11  5.880469e+11  4.898459e+11
# Other Stockholder Equity          1.091618e+09 -4.350197e+09 -1.381378e+10
# Property Plant Equipment          8.541236e+09  8.230854e+09  7.882695e+09
# Total Current Assets              2.426887e+11  3.464362e+11  2.302539e+11
# Long Term Investments             8.361773e+11  6.443177e+11  5.826741e+11
# Net Tangible Assets               1.349638e+11  1.183470e+11  1.007407e+11
# Short Term Investments            6.277788e+09  1.201339e+11  2.065050e+08
# Net Receivables                   1.121152e+10  1.130041e+10  1.444640e+10
# Long Term Debt                    1.682130e+11  1.900535e+11  1.960705e+11
# Accounts Payable                  7.024485e+11  6.334196e+11  5.187375e+11
# Inventory                                  NaN           NaN           NaN
#
#                                     2018-12-31
# Intangible Assets                 5.782032e+09
# Total Liab                        1.314649e+12
# Total Stockholder Equity          9.974197e+10
# Minority Interest                 2.510915e+09
# Other Current Liab                9.600237e+10
# Total Assets                      1.416901e+12
# Common Stock                      6.700000e+10
# Other Current Assets              6.577648e+10
# Retained Earnings                 4.261258e+10
# Other Liab                        2.403604e+10
# Treasury Stock                   -9.870615e+09
# Other Assets                      6.673905e+11
# Cash                              3.818834e+10
# Total Current Liabilities         1.082949e+12
# Deferred Long Term Asset Charges           NaN
# Short Long Term Debt              4.925471e+11
# Other Stockholder Equity         -8.037184e+09
# Property Plant Equipment          7.537617e+09
# Total Current Assets              6.071002e+11
# Long Term Investments             1.290911e+11
# Net Tangible Assets               9.395994e+10
# Short Term Investments            4.281338e+11
# Net Receivables                   7.407338e+10
# Long Term Debt                    2.076640e+11
# Accounts Payable                  4.860368e+11
# Inventory                         6.098800e+07

# %%
bbas3.quarterly_balance_sheet
# Out:
#                                     2021-12-31    2021-09-30    2021-06-30  \
# Intangible Assets                 7.031258e+09  5.044801e+09  4.764924e+09
# Total Liab                        1.787676e+12  1.827895e+12  1.714147e+12
# Total Stockholder Equity          1.419950e+11  1.445540e+11  1.432430e+11
# Minority Interest                 2.862168e+09  2.957922e+09  2.564049e+09
# Other Current Liab                6.841630e+10  6.582082e+10  5.988977e+10
# Total Assets                      1.932533e+12  1.975407e+12  1.859955e+12
# Common Stock                      9.000002e+10  9.000002e+10  9.000002e+10
# Other Current Assets              1.574565e+11  1.547226e+11  1.500463e+11
# Retained Earnings                 5.118029e+10  4.873072e+10  4.581490e+10
# Other Liab                        1.316896e+11  1.432052e+11  1.323728e+11
# Treasury Stock                    8.147050e+08  5.823264e+09  7.428113e+09
# Other Assets                      8.380945e+11  8.014245e+11  7.674020e+11
# Cash                              4.906528e+10  5.020002e+10  5.553814e+10
# Total Current Liabilities         1.487773e+12  1.514573e+12  1.420346e+12
# Deferred Long Term Asset Charges  5.662000e+10  5.826722e+10  5.981402e+10
# Short Long Term Debt              7.169084e+11  7.592318e+11  6.689553e+11
# Other Stockholder Equity          1.091618e+09  6.100177e+09  7.705026e+09
# Property Plant Equipment          8.541236e+09  7.987716e+09  7.921996e+09
# Total Current Assets              2.426887e+11  2.374406e+11  2.440016e+11
# Long Term Investments             8.361773e+11  9.235093e+11  8.358639e+11
# Net Tangible Assets               1.349638e+11  1.395092e+11  1.384781e+11
# Short Term Investments            6.277788e+09  7.039186e+09  1.294430e+10
# Net Receivables                   1.121152e+10  1.251019e+10  1.208478e+10
# Long Term Debt                    1.682130e+11  1.701173e+11  1.614289e+11
# Accounts Payable                  7.024485e+11  6.895199e+11  6.915006e+11
#
#                                     2021-03-31
# Intangible Assets                 4.977800e+09
# Total Liab                        1.691008e+12
# Total Stockholder Equity          1.354572e+11
# Minority Interest                 2.738063e+09
# Other Current Liab                5.718975e+10
# Total Assets                      1.829204e+12
# Common Stock                      9.000002e+10
# Other Current Assets              1.438797e+11
# Retained Earnings                 4.178280e+10
# Other Liab                        1.319297e+11
# Treasury Stock                    3.674374e+09
# Other Assets                      7.467113e+11
# Cash                              5.937222e+10
# Total Current Liabilities         1.380278e+12
# Deferred Long Term Asset Charges  5.765711e+10
# Short Long Term Debt              6.660683e+11
# Other Stockholder Equity          3.951977e+09
# Property Plant Equipment          7.999314e+09
# Total Current Assets              2.391154e+11
# Long Term Investments             8.304000e+11
# Net Tangible Assets               1.304794e+11
# Short Term Investments            7.689450e+09
# Net Receivables                   1.318717e+10
# Long Term Debt                    1.788007e+11
# Accounts Payable                  6.551342e+11

# %%
bbas3.cashflow
#bbas3.quarterly_cashflow
# Out:
#                                              2021-12-31    2020-12-31  \
# Investments                               -5.049078e+10 -9.416455e+10
# Change To Liabilities                      0.000000e+00  0.000000e+00
# Total Cashflows From Investing Activities -5.327815e+10 -9.564641e+10
# Net Borrowings                            -1.665358e+10 -1.278763e+10
# Total Cash From Financing Activities       4.744407e+10  1.011075e+11
# Change To Operating Activities            -1.612013e+11  4.105831e+10
# Net Income                                 1.971040e+10  1.269738e+10
# Change In Cash                            -1.216948e+11  1.042535e+11
# Effect Of Exchange Rate                    1.553477e+09  1.032067e+10
# Total Cash From Operating Activities      -1.174142e+11  8.847173e+10
# Depreciation                               2.413313e+09  3.155206e+09
# Other Cashflows From Investing Activities  2.031955e+09  2.265323e+09
# Dividends Paid                            -2.078966e+09 -2.404018e+09
# Other Cashflows From Financing Activities  7.055262e+10  1.180794e+11
# Change To Netincome                        3.000350e+10  3.322187e+10
# Capital Expenditures                      -1.755593e+09 -1.700104e+09
# Issuance Of Stock                                   NaN  1.526800e+07
#
#                                              2019-12-31    2018-12-31
# Investments                               -2.728768e+10 -1.153321e+10
# Change To Liabilities                      0.000000e+00  2.662160e+08
# Total Cashflows From Investing Activities -3.013845e+10 -1.059416e+10
# Net Borrowings                            -7.284291e+09 -3.097480e+09
# Total Cash From Financing Activities       1.918133e+10  2.679381e+10
# Change To Operating Activities            -4.258229e+09 -4.313130e+10
# Net Income                                 1.816207e+10  1.286203e+10
# Change In Cash                             1.160057e+10  1.315150e+10
# Effect Of Exchange Rate                   -1.587850e+08  2.522422e+09
# Total Cash From Operating Activities       2.271647e+10 -5.570568e+09
# Depreciation                               3.036181e+09  3.157990e+09
# Other Cashflows From Investing Activities  1.473059e+09  2.925249e+09
# Dividends Paid                            -2.451730e+09 -1.706455e+09
# Other Cashflows From Financing Activities  3.078126e+10  3.408120e+10
# Change To Netincome                        2.724141e+10  2.276248e+10
# Capital Expenditures                      -1.651586e+09 -1.361242e+09
# Issuance Of Stock                          2.805364e+09  1.661200e+07

# %%
bbas3.earnings
# Out:
#           Revenue     Earnings
# Year
# 2018  60334372000  12862026000
# 2019  61745862000  18162067000
# 2020  58483157000  12697385000
# 2021  74031801000  19710402000

# %%
bbas3.sustainability
# Out:
#                           Value
# 2022-5
# palmOil                   False
# controversialWeapons      False
# gambling                  False
# socialScore                9.21
# nuclear                   False
# furLeather                False
# alcoholic                 False
# gmo                       False
# catholic                  False
# socialPercentile           None
# peerCount                   174
# governanceScore           10.81
# environmentPercentile      None
# animalTesting             False
# tobacco                   False
# totalEsg                  20.62
# highestControversy            2
# esgPerformance         AVG_PERF
# coal                      False
# pesticides                False
# adult                     False
# percentile                26.56
# peerGroup                 Banks
# smallArms                 False
# environmentScore           0.59
# governancePercentile       None
# militaryContract          False

# %%
#recomendações de especialistas
bbas3.recommendations

# %%
bbas3.calendar
# Out:
#                                 Value
# Earnings Date     2022-05-12 10:00:00
# Earnings Average                 1.91
# Earnings Low                     1.81
# Earnings High                    2.04
# Revenue Average           24553400000
# Revenue Low               23088300000
# Revenue High              25676900000

# %%
bbas3.news
# Out:
# [{'link': 'https://finance.yahoo.com/m/1dbb64e6-667f-3a0d-83bb-bd734a8436ed/dow-jones-futures%3A-s%26p-500.html',
#   'providerPublishTime': 1652397932,
#   'publisher': "Investor's Business Daily",
#   'title': 'Dow Jones Futures: S&P 500 Flirts With Bear Market As Apple Breaks, Tesla Tested; These Stocks Rally',
#   'type': 'STORY',
#   'uuid': '1dbb64e6-667f-3a0d-83bb-bd734a8436ed'},
#  {'link': 'https://finance.yahoo.com/news/updated-wayne-farms-llc-recalls-232300257.html',
#   'providerPublishTime': 1652397780,
#   'publisher': 'GlobeNewswire',
#   'title': 'UPDATED: WAYNE FARMS, LLC RECALLS READY-TO-EAT CHICKEN BREAST FILLET PRODUCTS THAT MAY BE UNDERCOOKED',
#   'type': 'STORY',
#   'uuid': 'd67544e7-c6c3-32f3-b5c1-0781c9810559'},
#  {'link': 'https://finance.yahoo.com/news/winshear-provides-corporate-exploration-updates-232200011.html',
#   'providerPublishTime': 1652397720,
#   'publisher': 'GlobeNewswire',
#   'title': 'Winshear Provides Corporate and Exploration Updates',
#   'type': 'STORY',
#   'uuid': '30f4608b-2d58-379f-a50d-874839c8606a'},
#  {'link': 'https://finance.yahoo.com/news/headwater-exploration-inc-announces-results-232000057.html',
#   'providerPublishTime': 1652397600,
#   'publisher': 'CNW Group',
#   'title': 'HEADWATER EXPLORATION INC. ANNOUNCES RESULTS OF DIRECTORS VOTE',
#   'type': 'STORY',
#   'uuid': '920d1fd4-9102-32b2-bb3e-1676e33057ac'},
#  {'link': 'https://finance.yahoo.com/m/f74b8c5b-b0c2-34a1-a495-c63d27c7c063/baby-formula-shortage.html',
#   'providerPublishTime': 1652397480,
#   'publisher': 'MarketWatch',
#   'title': 'Baby formula shortage persists, but experts warn it’s dangerous to make your own or buy it online from overseas',
#   'type': 'STORY',
#   'uuid': 'f74b8c5b-b0c2-34a1-a495-c63d27c7c063'},
#  {'link': 'https://finance.yahoo.com/m/6e8fb483-3ff2-3a41-8275-9e9949427873/are-any-marijuana-stocks-on.html',
#   'providerPublishTime': 1652397343,
#   'publisher': "Investor's Business Daily",
#   'title': 'Are Any Marijuana Stocks On U.S. Exchanges Buys After Aurora, Cronos Earnings?',
#   'type': 'STORY',
#   'uuid': '6e8fb483-3ff2-3a41-8275-9e9949427873'},
#  {'link': 'https://finance.yahoo.com/news/cookie-co-announces-opening-location-231500040.html',
#   'providerPublishTime': 1652397300,
#   'publisher': 'News Direct',
#   'title': 'Cookie Co. Announces Opening of New Location in Riverside, California',
#   'type': 'STORY',
#   'uuid': 'dde44385-1656-3b80-ac3b-df73876ad1d6'},
#  {'link': 'https://finance.yahoo.com/news/cathedral-energy-services-announces-director-231200635.html',
#   'providerPublishTime': 1652397120,
#   'publisher': 'CNW Group',
#   'title': 'CATHEDRAL ENERGY SERVICES ANNOUNCES DIRECTOR ELECTION RESULTS',
#   'type': 'STORY',
#   'uuid': 'fb4459aa-69ba-3c46-a4ac-b8ba23d0c98f'}]

# %% [markdown]
# Para utilizar o recurso de cache, ou seja, armazenar chamadas à API de sessões anteriores, ou mesmo customizar o cabeçalho `User-agent`, utilize o código abaixo (descrito na documentação da biblioteca).

# %%
# !pip install requests_cache -q
import requests_cache

session = requests_cache.CachedSession('yfinance.cache')
session.headers['User-agent'] = 'my-program/1.0'
ticker = yf.Ticker('bbas3.sa itub4.sa', session=session)

ticker.actions
# Out:
#      |████████████████████████████████| 47 kB 4.8 MB/s
#      |████████████████████████████████| 138 kB 48.7 MB/s
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.27.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# - BBAS3.SA ITUB4.SA: No data found, symbol may be delisted
# []

# %% [markdown]
# Para inicializar vários ativos instanciados em classes `Ticker`, informe os símbolos das ações da seguinte maneira.

# %%
tickers = yf.Tickers('bbas3.sa itub3.sa petr4.sa')
# returna uma tupla com objetos Ticker

# para acessar cada ativo individual
tickers.tickers['BBAS3.SA'].info
tickers.tickers['ITUB3.SA'].history(period="1mo")
tickers.tickers['PETR4.SA'].actions
# Out:
#             Dividends  Stock Splits
# Date
# 2005-04-01   0.133288           0.0
# 2005-07-01   0.250663           0.0
# 2005-09-01   0.000000           4.0
# 2006-01-02   0.259000           0.0
# 2006-04-04   0.132700           0.0
# 2006-11-01   0.500750           0.0
# 2007-01-02   0.225000           0.0
# 2007-04-03   0.175000           0.0
# 2007-08-20   0.251700           0.0
# 2007-10-08   0.256500           0.0
# 2008-01-14   0.155300           0.0
# 2008-04-07   0.102600           0.0
# 2008-04-28   0.000000           2.0
# 2008-12-29   0.042600           0.0
# 2009-04-09   0.351600           0.0
# 2009-07-06   0.300000           0.0
# 2009-10-01   0.200000           0.0
# 2009-12-21   0.200000           0.0
# 2010-04-23   0.133200           0.0
# 2010-05-24   0.170000           0.0
# 2010-08-02   0.170000           0.0
# 2010-11-03   0.140000           0.0
# 2010-12-22   0.200000           0.0
# 2011-03-22   0.173420           0.0
# 2011-04-29   0.126500           0.0
# 2011-05-12   0.213600           0.0
# 2011-08-03   0.207300           0.0
# 2011-11-14   0.200000           0.0
# 2012-01-03   0.177300           0.0
# 2012-03-20   0.124400           0.0
# 2012-05-14   0.200000           0.0
# 2013-04-30   0.386170           0.0
# 2014-04-03   0.967200           0.0
# 2018-05-22   0.050000           0.0
# 2018-08-14   0.050000           0.0
# 2018-11-22   0.100000           0.0
# 2018-12-26   0.716563           0.0
# 2019-04-26   0.019494           0.0
# 2019-05-22   0.100000           0.0
# 2019-08-13   0.200000           0.0
# 2019-11-12   0.200925           0.0
# 2019-12-27   0.421942           0.0
# 2020-04-23   0.000449           0.0
# 2020-04-28   0.000449           0.0
# 2020-07-23   0.000461           0.0
# 2021-04-15   0.792834           0.0
# 2021-08-17   1.609911           0.0
# 2021-12-02   3.250487           0.0
# 2022-04-14   2.942264           0.0

# %%
# ace
tickers.symbols
# Out:
# ['BBAS3.SA', 'ITUB3.SA', 'PETR4.SA']

# %% [markdown]
# ## Bibliotecas para Análise Quantitativa
#
# Conheça as principais bibliotecas para análise de ativos, e que serão usadas para a construção do Dashboard.

# %% [markdown]
# ### Portfolio Analytics for Quants (QuantStats)
#
# Essa é uma biblioteca para proceder com análises quantitativas, trazendo profundidade nas análises e métricas de risco.
#
# A biblioteca `quantstats` é composta de 3 módulos principais:
#
# 1. `quantstats.stats` - para calcular várias métricas de perfomance, como Índice de Sharpe, Win rate, Volatilidade, etc.
#
# 2. `quantstats.plots` - para visualizar performance, drawdowns, rolling statistics, monthly returns, entre outros.
#
# 3. `quantstats.reports` - para gerar relatórios de métricas, assim como gerar planilhas que podem ser salvas em um arquivo HTML.
#
# Assim como fizemos com a biblioteca `yfinance`, é necessário proceder com a instalação manual da biblioteca no Colab.

# %%
# instalar biblioteca que não acompanha o Colab por padrão
# !pip install quantstats -q
# Out:
#      |████████████████████████████████| 41 kB 287 kB/s

# %%
# importar a biblioteca quantstats
import quantstats as qs

# %%
# extender as funcionalidades para o Pandas
qs.extend_pandas()

# %%
# baixar dados para a ação ITUB3
itub3 = qs.utils.download_returns('ITUB3.SA')

# %%
# mostrar o índice de sharpe
qs.stats.sharpe(itub3)
# Out:
# 0.547929664883534

# %%
# ou usando a funcionalidade extend_pandas
itub3.sharpe()
# Out:
# 0.547929664883534

# %%
# visualizando a performance de uma ação
qs.plots.snapshot(itub3, title="Performance de ITUB3")
# Out:
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# Uma das funcionalidades mais poderosas da biblioteca `quantstats` é a sua capacidade de gerar relatórios com apenas uma linha de código.
#
# Dentro da ferramenta você encontrará 7 tipos possíveis de relatórios:
#
# 1. `qs.reports.metrics(mode='basic', ...)`
#
# 2. `qs.reports.metrics(mode='full", ...)`
#
# 3. `qs.reports.plots(mode='basic", ...)`
#
# 4. `qs.reports.plots(mode='full", ...)`
#
# 5. `qs.reports.basic(...)`
#
# 6. `qs.reports.full(...)`
#
# 7. `qs.reports.html(...)`
#
# Um parâmetro importante que pode ser passado, é o símbolo de um ativo para servir de benchmar.

# %%
# exemplo de relatório completo
qs.reports.full(itub3, benchmark="^BVSP")
# Out:
# [Performance Metrics]
#
#                            Strategy    Benchmark
# -------------------------  ----------  -----------
# Start Period               2000-01-03  2000-01-03
# End Period                 2022-05-12  2022-05-12
# Risk-Free Rate             0.0%        0.0%
# Time in Market             81.0%       99.0%
#
# Cumulative Return          1,506.73%   524.26%
# CAGR﹪                     13.22%      8.53%
#
# Sharpe                     0.55        0.43
# Prob. Sharpe Ratio         99.51%      97.97%
# Smart Sharpe               0.53        0.42
# Sortino                    0.8         0.62
# Smart Sortino              0.77        0.59
# Sortino/√2                 0.57        0.44
# Smart Sortino/√2           0.55        0.42
# Omega                      1.11        1.11
#
# Max Drawdown               -55.43%     -59.96%
# Longest DD Days            1099        3400
# Volatility (ann.)          32.22%      28.1%
# R^2                        0.33        0.33
# Information Ratio          0.01        0.01
# Calmar                     0.24        0.14
# Skew                       0.02        -0.13
# Kurtosis                   7.15        6.35
#
# Expected Daily %           0.05%       0.03%
# Expected Monthly %         1.04%       0.68%
# Expected Yearly %          12.83%      8.29%
# Kelly Criterion            5.23%       3.06%
# Risk of Ruin               0.0%        0.0%
# Daily Value-at-Risk        -3.27%      -2.86%
# Expected Shortfall (cVaR)  -3.27%      -2.86%
#
# Max Consecutive Wins       9           11
# Max Consecutive Losses     9           8
# Gain/Pain Ratio            0.11        0.08
# Gain/Pain (1M)             0.58        0.44
#
# Payoff Ratio               1.04        0.99
# Profit Factor              1.11        1.08
# Common Sense Ratio         1.23        1.05
# CPC Index                  0.6         0.55
# Tail Ratio                 1.11        0.97
# Outlier Win Ratio          4.47        4.12
# Outlier Loss Ratio         3.03        3.81
#
# MTD                        4.23%       -2.03%
# 3M                         -8.18%      -6.94%
# 6M                         1.98%       -1.89%
# YTD                        10.15%      0.83%
# 1Y                         -13.22%     -14.05%
# 3Y (ann.)                  -8.69%      2.28%
# 5Y (ann.)                  3.72%       11.38%
# 10Y (ann.)                 10.74%      5.92%
# All-time (ann.)            13.22%      8.53%
#
# Best Day                   16.08%      14.66%
# Worst Day                  -20.07%     -14.78%
# Best Month                 26.27%      17.92%
# Worst Month                -26.63%     -29.9%
# Best Year                  62.18%      93.44%
# Worst Year                 -36.73%     -41.22%
#
# Avg. Drawdown              -6.66%      -4.67%
# Avg. Drawdown Days         64          65
# Recovery Factor            27.18       8.74
# Ulcer Index                0.16        0.22
# Serenity Index             6.28        1.07
#
# Avg. Up Month              7.86%       6.45%
# Avg. Down Month            -6.74%      -5.79%
# Win Days %                 51.6%       51.84%
# Win Month %                55.22%      55.02%
# Win Quarter %              66.67%      57.78%
# Win Year %                 69.57%      60.87%
#
# Beta                       0.66        -
# Alpha                      0.1         -
# Correlation                57.27%      -
# Treynor Ratio              2295.19%    -
#
#
#
# [5 Worst Drawdowns]
#
#     Start       Valley      End           Days    Max Drawdown    99% Max Drawdown
# --  ----------  ----------  ----------  ------  --------------  ------------------
#  1  2007-10-10  2008-10-27  2010-10-13    1099          -55.43              -50.21
#  2  2002-03-06  2002-10-15  2003-09-01     544          -43.63              -42.16
#  3  2020-01-03  2020-03-23  2022-05-12     860          -38.54              -36.85
#  4  2014-09-03  2016-01-21  2016-08-30     727          -34.78              -33.31
#  5  2010-11-11  2011-08-08  2012-02-16     462          -32.85              -27.43
#
#
#
# [Strategy Visualization]
# via Matplotlib

# %%
# gerar relatório em um arquivo html
qs.reports.html(itub3, benchmark="^BVSP", output='relatorio.html')

# %%
# gerar itens do relatório individualmente
itub3.monthly_returns()
# Out:
#            JAN       FEB       MAR       APR       MAY       JUN       JUL  \
# 2000 -0.092857 -0.039369  0.065573 -0.115384  0.052173  0.148761  0.028777
# 2001  0.016216 -0.079786 -0.005781  0.005814  0.098265 -0.010527  0.010639
# 2002 -0.005713  0.120689 -0.051282  0.016216 -0.069150 -0.142856 -0.213333
# 2003 -0.038461 -0.026667  0.253425 -0.021858  0.027933 -0.021740  0.027778
# 2004  0.019762  0.007751 -0.038462 -0.024000 -0.032787  0.080508 -0.019608
# 2005 -0.045714  0.152696  0.096104 -0.087678 -0.012987 -0.052633  0.027778
# 2006  0.212767  0.035088 -0.050848  0.017858 -0.070176  0.018868  0.037037
# 2007  0.030768 -0.059533 -0.031746  0.114754  0.117647  0.013158  0.038961
# 2008 -0.185933  0.144776 -0.072908  0.140947  0.041121 -0.134488  0.056419
# 2009 -0.072992 -0.043207  0.147642  0.142234  0.052161 -0.021202  0.069678
# 2010 -0.031197  0.004499  0.044724 -0.015513 -0.074037 -0.061067  0.174965
# 2011 -0.057983  0.042156  0.047681  0.006776 -0.037411  0.016166 -0.107120
# 2012  0.129342  0.039686 -0.031442 -0.108799 -0.039644 -0.019109  0.119906
# 2013  0.075293  0.017177  0.077958 -0.059699  0.019803 -0.075511 -0.015247
# 2014 -0.063063  0.075465  0.097884  0.076971 -0.058687  0.031048  0.096976
# 2015 -0.067369  0.117353 -0.016354  0.078502 -0.063879  0.023578 -0.055580
# 2016 -0.079178  0.034346  0.176911  0.070238 -0.108037  0.022196  0.128245
# 2017  0.072202  0.113606 -0.035005  0.009035 -0.051843  0.008524  0.017063
# 2018  0.176908  0.031319  0.035448 -0.022498 -0.133265 -0.060087  0.114672
# 2019  0.094390 -0.022329 -0.040039 -0.016256  0.026419  0.034391 -0.039049
# 2020 -0.080431 -0.012093 -0.227837 -0.002946 -0.002047  0.094641  0.038148
# 2021 -0.073268 -0.088731  0.077339 -0.023024  0.088952  0.006967  0.027877
# 2022  0.158221 -0.010368  0.082831 -0.148516  0.042251  0.000000  0.000000
#
#                AUG           SEP       OCT       NOV           DEC       EOY
# 2000  6.293741e-02 -4.605210e-02  0.117242  0.043209  9.467471e-02  0.331214
# 2001 -7.894833e-02 -8.571322e-02  0.156249 -0.054055 -2.220446e-16 -0.025606
# 2002  1.864406e-01 -1.571428e-01  0.262713 -0.046980  9.859113e-02 -0.038936
# 2003  9.729867e-02 -1.477881e-02  0.055000  0.056871  1.345298e-01  0.542525
# 2004  2.000021e-02  7.058943e-02  0.073259  0.017066  1.744955e-01  0.354676
# 2005  1.081087e-01  2.195112e-01 -0.099999  0.066667 -2.083353e-02  0.331518
# 2006 -1.785650e-02 -1.110223e-16  0.090909  0.000000  8.333440e-02  0.388015
# 2007  2.220446e-16  7.500025e-02  0.057907 -0.031905 -2.272688e-02  0.330484
# 2008 -1.387948e-01  1.423177e-01 -0.266281 -0.049500 -1.727802e-02 -0.304303
# 2009  8.053438e-02  8.572131e-02 -0.057546  0.109051  9.763981e-03  0.515162
# 2010 -2.572587e-02  5.333200e-02  0.029574 -0.023253  3.872958e-04  0.082587
# 2011 -6.195669e-02  1.256726e-03  0.118173 -0.034681 -7.393578e-03 -0.041273
# 2012  5.198942e-03 -3.695820e-02 -0.023333  0.094673  8.259542e-02  0.215806
# 2013 -1.231005e-02  7.262344e-02  0.083845 -0.062069 -3.102577e-02  0.111370
# 2014  1.321625e-01 -1.553047e-01  0.040930  0.046992 -5.514115e-02  0.281174
# 2015 -1.074660e-01 -2.213362e-02  0.012038  0.022393 -2.158556e-02 -0.081556
# 2016  6.102826e-02  1.645210e-02  0.176014 -0.081770 -2.511392e-03  0.415094
# 2017  9.133695e-02  7.698763e-02  0.000912 -0.033720  2.002892e-02  0.295193
# 2018 -4.929669e-02  8.426010e-03  0.124851  0.092390 -2.507774e-02  0.280908
# 2019  1.898464e-02  7.863612e-03  0.035376 -0.038357  7.092751e-02  0.146247
# 2020 -9.133309e-02 -5.167484e-02  0.028786  0.172775  8.736262e-02 -0.020070
# 2021  4.669014e-02 -5.643892e-02 -0.220678 -0.030745 -4.941395e-02 -0.282373
# 2022  0.000000e+00  0.000000e+00  0.000000  0.000000  0.000000e+00  0.107633

# %%
# gerar itens do relatório individualmente
itub3.plot_monthly_heatmap()

# %%
# gerar itens do relatório individualmente
itub3.volatility()
# Out:
# 0.3221757834153608

# %%
# listar todas as features disponíveis
dir(qs.stats)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_ceil',
#  '_linregress',
#  '_norm',
#  '_np',
#  '_pd',
#  '_sqrt',
#  '_utils',
#  'adjusted_sortino',
#  'autocorr_penalty',
#  'avg_loss',
#  'avg_return',
#  'avg_win',
#  'best',
#  'cagr',
#  'calmar',
#  'common_sense_ratio',
#  'comp',
#  'compare',
#  'compsum',
#  'conditional_value_at_risk',
#  'consecutive_losses',
#  'consecutive_wins',
#  'cpc_index',
#  'cvar',
#  'distribution',
#  'drawdown_details',
#  'expected_return',
#  'expected_shortfall',
#  'exposure',
#  'gain_to_pain_ratio',
#  'geometric_mean',
#  'ghpr',
#  'greeks',
#  'implied_volatility',
#  'information_ratio',
#  'kelly_criterion',
#  'kurtosis',
#  'max_drawdown',
#  'monthly_returns',
#  'omega',
#  'outlier_loss_ratio',
#  'outlier_win_ratio',
#  'outliers',
#  'payoff_ratio',
#  'pct_rank',
#  'probabilistic_adjusted_sortino_ratio',
#  'probabilistic_ratio',
#  'probabilistic_sharpe_ratio',
#  'probabilistic_sortino_ratio',
#  'profit_factor',
#  'profit_ratio',
#  'r2',
#  'r_squared',
#  'rar',
#  'recovery_factor',
#  'remove_outliers',
#  'risk_of_ruin',
#  'risk_return_ratio',
#  'rolling_greeks',
#  'rolling_sharpe',
#  'rolling_sortino',
#  'rolling_volatility',
#  'ror',
#  'serenity_index',
#  'sharpe',
#  'skew',
#  'smart_sharpe',
#  'smart_sortino',
#  'sortino',
#  'tail_ratio',
#  'to_drawdown_series',
#  'treynor_ratio',
#  'ulcer_index',
#  'ulcer_performance_index',
#  'upi',
#  'value_at_risk',
#  'var',
#  'volatility',
#  'warn',
#  'win_loss_ratio',
#  'win_rate',
#  'worst']

# %% [markdown]
# ### Technical Analysis Library (TA)
#
# `ta` é uma biblioteca voltada para a análise de séries temporais financeiras (abertura, fechamento, máxima, mínima e volume).
#
# Pensada para servir como apoio às técnicas de *feature engineering* no contexto do Python, a mesma é construída em cima da conhecida biblioteca `pandas`.
#
# Assim como as anteriores, faz-se necessária sua instalação dentro do ambiente Google Colab.

# %%
# instalar ta
# !pip install ta -q
# Out:
#   Building wheel for ta (setup.py) ... done

# %%
# importar ta
import ta

# ou importar apenas aquilo que vamos usar da biblioteca
from ta.volatility import BollingerBands

# %%
# baixar dados da PETR4 para exemplo
df = yf.download('petr4.sa')
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#              Open   High    Low  Close  Adj Close       Volume
# Date
# 2000-01-03  5.875  5.875  5.875  5.875   2.930678  35389440000
# 2000-01-04  5.550  5.550  5.550  5.550   2.768553  28861440000
# 2000-01-05  5.494  5.494  5.494  5.494   2.740619  43033600000
# 2000-01-06  5.475  5.475  5.475  5.475   2.731141  34055680000
# 2000-01-07  5.500  5.500  5.500  5.500   2.743612  20912640000

# %% [markdown]
# Veja um exemplo onde facilmente conseguimos calcular as bandas superior e inferior de Bollinger.
#
# #### Bandas de Bollinger
#
# Como exemplo de aplicação das Bandas de Bollinger, vamos relembrar que elas consistem em três partes: Banda do Meio, Banda Superior e Banda Inferior.
#
# Muito utilizadas quando se busca um indicador de volatilidade de um determinado ativo, elas servem de insumos para o processo decisório de compra ou venda de um papel.
#
#
#
# <center><img src="https://origin2.cdn.componentsource.com/sites/default/files/resources/dundas/538216/Documentation/images/BollingerBands.png" height="200px"></center>
#
#
# Por padrão, é utilizado o valor de 20 períodos para seu cálculo. Mas claro que pode ser alterado de acordo com a análise desejada, sendo o período `n = 20` apenas uma recomendação do próprio Bollinger, criador do indicador.
#
# Matematicamente, os cálculos das Bandas é definido da seguinte maneira, sendo $y$ o valor do Fechamento (`Close`) da cotação.
#
# \begin{align*}
# &\mathbf{MA} = \frac{\sum\limits_{i=1}^n y_i}{n}\\
# &\mathbf{UpperBB} = MA + D \sqrt{\frac{\sum\limits_{i=1}^n (y_i - MA)^2}{n}}\\
# &\mathbf{LowerBB} = MA + D \sqrt{\frac{\sum\limits_{i=1}^n (y_i - MA)^2}{n}}
# \end{align*}
#
# Um investidor poderia desejar calcular tais valores, mas observe como tudo se torna muito simples e direto com a biblioteca `ta`.

# %%
bb = BollingerBands(close=df["Close"], window=20, window_dev=2)

# %% [markdown]
# Agora, basta apenas extrair os cálculos desse indicador. No caso, irei associar cada um deles a uma nova coluna dentro do mesmo DataFrame.

# %%
df['bb_bbm'] = bb.bollinger_mavg()
df['bb_bbh'] = bb.bollinger_hband()
df['bb_bbl'] = bb.bollinger_lband()

# %%
df.tail()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2022-05-06  32.689999  33.119999  31.900000  33.060001  33.060001  129570200
# 2022-05-09  32.700001  33.040001  32.060001  32.160000  32.160000   92314500
# 2022-05-10  32.360001  32.849998  32.200001  32.439999  32.439999   60330600
# 2022-05-11  32.779999  33.910000  32.689999  33.570000  33.570000  108895400
# 2022-05-12  33.259998  34.080002  33.259998  33.830002  33.830002  114034500
#
#              bb_bbm     bb_bbh     bb_bbl
# Date
# 2022-05-06  31.7380  34.940090  28.535909
# 2022-05-09  31.6440  34.676130  28.611869
# 2022-05-10  31.5555  34.379033  28.731967
# 2022-05-11  31.5365  34.299797  28.773203
# 2022-05-12  31.5355  34.295460  28.775540

# %% [markdown]
# De maneira simples, com poucas linhas de código, calculamos os valores das Bandas de Bollinger.
#
# Veja como é simples e direto plotar essas informações diretamente do DataFrame.

# %%
# importar matplotlib
import matplotlib.pyplot as plt

plt.plot(df["Close"][:400])
plt.plot(df["bb_bbh"][:400])
plt.plot(df["bb_bbl"][:400])
